# %% [markdown]
# # Proyecto de Ciencia de Datos: Supermarket Sales
# ###1. Objetivo del Proyecto:
# El objetivo principal es analizar los datos de ventas de un supermercado, identificar patrones, entender el comportamiento de los clientes y construir un modelo de series temporales para predecir las ventas futuras.
#
# ###2. Conjunto de Datos:
# Utiliza un conjunto de datos que contenga información sobre las ventas en el supermercado. Puedes obtener datos de ventas diarias o semanales, detalles del producto, precios, promociones, etc. Asegúrate de tener datos históricos para poder realizar un análisis de series temporales.
#
# ###3. Pasos del Proyecto:
# 3.1 Análisis Exploratorio de Datos (EDA):
#
# a. Exploración de Datos Básicos: Carga y exploración inicial del conjunto de datos. Verificación de la consistencia de los datos, identificación y manejo de valores faltantes o duplicados.
#
# b. Análisis de Patrones Temporales: Visualización de las ventas a lo largo del tiempo. Descomposición de series temporales para identificar tendencias, estacionalidades y residuos.
#
# c. Análisis de Productos Más Vendidos: Identificación de los productos más vendidos. Análisis de la contribución de diferentes productos a las ventas totales.
#
# d. Correlaciones y Análisis de Factores: Identificación de correlaciones entre variables (por ejemplo, promociones y ventas). Análisis de factores que pueden influir en las ventas.
#
# ###4. Construcción del Modelo de Series Temporales:
# a. Preparación de Datos: Transformación de datos para adecuarlos al modelo de series temporales. División de datos en conjuntos de entrenamiento y prueba.
#
# b. Selección de Modelo: Prueba de varios modelos de series temporales como ARIMA, SARIMA, LSTM, etc. Evaluación de la adecuación del modelo utilizando métricas como MAE, MSE, RMSE.
#
# c. Ajuste del Modelo: Ajuste del modelo seleccionado utilizando el conjunto de entrenamiento. Validación del modelo con el conjunto de prueba.
#
# d. Predicciones Futuras: Realización de predicciones para un periodo futuro. Visualización de las predicciones en comparación con los datos reales.
#
# ###5. Conclusiones y Recomendaciones:
# a. Resumen de Resultados: Resumen de hallazgos del EDA. Desempeño del modelo de series temporales.
#
# b. Recomendaciones: Propuestas para mejorar las ventas basadas en los resultados obtenidos.
#
# ###6. Documentación y Presentación:
# a. Documentación del Código: Comentarios claros y explicativos en el código. Uso de Markdown para explicar el análisis y la metodología.
#
# b. Presentación: Creación de una presentación (puede ser en Jupyter Notebook, PowerPoint, etc.). Inclusión de gráficos, visualizaciones y conclusiones clave.

# %% [markdown]
# ## Este código realiza lo siguiente: ##
#
# Carga el conjunto de datos.
#
# Muestra los primeros registros, información general y estadísticas descriptivas.
#
# Identifica y muestra la cantidad de valores faltantes por columna.
#
# Identifica y muestra el número de valores duplicados.
#
# Realiza un manejo básico de valores faltantes y duplicados.
#
# Visualiza la distribución de las ventas como ejemplo.

# %% [markdown]
# # Importar bibliotecas necesarias

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Montando dataset

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/Datasets/supermarket_sales - Sheet1.csv'

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datasets/supermarket_sales - Sheet1.csv')
print(df.head())
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# # Información general sobre el conjunto de datos

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# # Estadísticas descriptivas para variables numéricas

# %%
print(df.describe())
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %% [markdown]
# # Verificación de valores faltantes

# %%
missing_values = df.isnull().sum()
print("\nValores faltantes por columna:\n", missing_values)
# Out:
# Valores faltantes por columna:
#  Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# # Verificación de valores duplicados

# %%
duplicated_values = df.duplicated().sum()
print("\nNúmero de valores duplicados:", duplicated_values)
# Out:
# Número de valores duplicados: 0

# %% [markdown]
# # Manejo de valores faltantes

# %%
# Por ejemplo, eliminar filas con valores faltantes
df_cleaned = df.dropna()

# %% [markdown]
# # Manejo de valores duplicados

# %%
# Por ejemplo, eliminar duplicados manteniendo la primera ocurrencia
df_no_duplicates = df.drop_duplicates(keep='first')

# %% [markdown]
# # Visualización de la distribución de la variable "Quantity"

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['Quantity'], bins=30, kde=True, color='green')  # Cambiar a 'Quantity'
plt.title('Distribución de Cantidad de Productos Vendidos')
plt.xlabel('Cantidad')
plt.ylabel('Frecuencia')
plt.show()
