# %% [markdown]
# # Paso 1: Importar bibliotecas y cargar datos

# %%
import pandas as pd

# Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Ruta del archivo CSV en tu Google Drive
file_path = '/content/drive/MyDrive/Colab Notebooks/Datasets/Top 50 Fast-Food Chains in USA.csv'

# Cargar el conjunto de datos
df = pd.read_csv(file_path)

# Verificar las primeras filas para entender la estructura del conjunto de datos
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#   Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 0           Arby’s                                            4462
# 1   Baskin-Robbins                                             686
# 2        Bojangles                                            1485
# 3      Burger King                                           10033
# 4       Carl’s Jr.                                            1560
#
#    Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 0                                              1309               2293
# 1                                               296               2317
# 2                                              1924                496
# 3                                              1470               7054
# 4                                              1400               1011
#
# ...

# %% [markdown]
# # Paso 2: Exploración de datos

# %%
# Resumen estadístico del conjunto de datos
df.describe()

# Información sobre el tipo de datos y valores nulos
df.info()

# Conteo de valores únicos en cada columna
df.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Fast-Food Chains                                  50 non-null     object
#  1   U.S. Systemwide Sales (Millions - U.S Dollars)    50 non-null     int64
#  2   Average Sales per Unit (Thousands - U.S Dollars)  50 non-null     int64
#  3   Franchised Stores                                 50 non-null     int64
#  4   Company Stores                                    50 non-null     int64
#  5   2021 Total Units                                  50 non-null     int64
#  6   Total Change in Units from 2020                   50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB
# Fast-Food Chains                                    50
# U.S. Systemwide Sales (Millions - U.S Dollars)      49
# ...

# %% [markdown]
# # Paso 3: Comparación de características

# %%
print(df.columns)
# Out:
# Index(['Fast-Food Chains', 'U.S. Systemwide Sales (Millions - U.S Dollars)',
#        'Average Sales per Unit (Thousands - U.S Dollars)', 'Franchised Stores',
#        'Company Stores', '2021 Total Units',
#        'Total Change in Units from 2020'],
#       dtype='object')

# %%
# Comparación de características de las cadenas de comida rápida
# Puedes utilizar gráficos de barras, diagramas de dispersión, etc.

import matplotlib.pyplot as plt
import seaborn as sns

# Ejemplo de comparación de la clasificación y el número total de unidades en 2021
plt.figure(figsize=(12, 8))
sns.barplot(x='2021 Total Units', y='Fast-Food Chains', data=df.head(10))
plt.title('Top 10 Fast-Food Chains in USA - Número Total de Unidades en 2021')
plt.xlabel('Número Total de Unidades en 2021')
plt.ylabel('Nombre de la Cadena')
plt.show()
