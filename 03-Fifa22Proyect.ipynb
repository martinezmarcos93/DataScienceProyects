# %% [markdown]
# Explora las columnas y las primeras filas para entender la estructura del conjunto de datos.
#
# # Limpieza de Datos:
#
# Maneja valores nulos o faltantes.
# Elimina columnas irrelevantes o duplicadas.
# Convierte tipos de datos si es necesario.
# Asegúrate de que los nombres de las columnas sean descriptivos.
# Análisis Exploratorio de Datos (EDA):
#
# Realiza visualizaciones para entender la distribución de las estadísticas.
# Identifica tendencias a lo largo de los años.
# Examina la relación entre diferentes estadísticas y el rendimiento general del jugador.
#
# # Preparación de Datos:
#
# Codifica variables categóricas si es necesario.
# Divide el conjunto de datos en conjuntos de entrenamiento y prueba.
# Construcción del Modelo:
#
# Selecciona un modelo de regresión (puede ser lineal, regresión logística, etc.) para predecir el rendimiento de un jugador.
# Divide el conjunto de datos en variables predictoras (características) y la variable objetivo (rendimiento).
#
# # Entrenamiento del Modelo:
#
# Utiliza el conjunto de entrenamiento para entrenar tu modelo.
# Ajusta los hiperparámetros si es necesario.
# Evaluación del Modelo:
#
# Evalúa el rendimiento del modelo utilizando el conjunto de prueba.
# Utiliza métricas de evaluación apropiadas para problemas de regresión.
# Interpretación de Resultados:
#
# Analiza la importancia de las diferentes características en la predicción del rendimiento del jugador.
# Optimización y Ajuste:
#
# Itera en el modelo según sea necesario.
# Ajusta parámetros para mejorar el rendimiento.
# Documentación y Presentación:
#
# # Documenta tus pasos y decisiones.
# Presenta tus hallazgos y resultados de manera clara y comprensible.

# %%
# Importar las bibliotecas necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Montar Google Drive si aún no lo has hecho
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cargar el conjunto de datos desde Google Drive
file_path = '/content/drive/MyDrive/Colab Notebooks/Datasets/Career Mode female player datasets - FIFA 16-22.xlsx'  # Reemplaza 'your_path' con la ruta correcta en tu Google Drive
df = pd.read_excel(file_path)

# Mostrar las primeras filas del conjunto de datos
print(df.head())
# Out:
#    sofifa_id                                         player_url  short_name  \
# 0     226324  https://sofifa.com/player/226324/carli-lloyd/1...    C. Lloyd
# 1     226328  https://sofifa.com/player/226328/megan-rapinoe...  M. Rapinoe
# 2     226334  https://sofifa.com/player/226334/abby-wambach/...  A. Wambach
# 3     226362  https://sofifa.com/player/226362/louisa-necib/...    L. Nécib
# 4     226373  https://sofifa.com/player/226373/nadine-kessle...   N. Keßler
#
#             long_name player_positions  overall  potential  value_eur  \
# 0  Carli Anne Hollins  CM, CAM, LM, ST       91         91        NaN
# 1  Megan Anna Rapinoe           LM, CM       90         90        NaN
# 2        Abby Wambach               ST       90         90        NaN
# 3        Louisa Nécib          LM, CAM       90         90        NaN
# 4       Nadine Keßler               CM       89         89        NaN
#
#    wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# ...

# %%
print(df.columns)
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name',
#        'player_positions', 'overall', 'potential', 'value_eur', 'wage_eur',
#        'age',
#        ...
#        'lcb', 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url',
#        'club_flag_url', 'nation_logo_url', 'nation_flag_url'],
#       dtype='object', length=110)
